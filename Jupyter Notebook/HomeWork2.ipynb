# %% [markdown]
# #Домашнее задание №2

# %% [markdown]
# ##Задача №1
# Считать данные с помощью panda. Вывести на экран первые 5 строк. Посмотреть на описание признаков и на их содержание

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ##Задача №2
# Проведите первичный анализ данных. Изучите типы данных. Найдите количество пропущенных ячеек в данных. Посчитайте основные статистики по всем признакам и поизучайте их. Пишите выводы.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# ### Ответ: Таблица не содердит пропусков. Состав: вещественные значения float64(5), целочисленные значения int64(15), строковые значения object(1).

# %% [markdown]
# ##Задача №3
# ### Ответ
# * 3.1 В каком диапазоне изменяются стоимости недвижимости?
# Стоимость изменяется в столбце price
# * 3.2 Какую долю в среднем занимают жилая площадь от всей площади по всем домам?
# Средняя 1986.552492, отклонение 685.391304
# * 3.3 Как много домов с разными этажами в данных?
# Ответ:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# * 3.4 Насколько хорошие состояния у домов в данных?
# 50% домов старше 1975 и не имеют реновации. Жилой фонд достаточно старый.
# * 3.5 Найдите года, когда построили первый дом, когда построили последний дом в данных?
# Самый новый дом построен в 2015, самый старый дом в 1900

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df['yr_built'].min()
# Out:
# 1900

# %%
df['yr_built'].max()
# Out:
# 2015

# %%
df['floors'].value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
print(df.describe(include=['object']))
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %% [markdown]
# ## Задача №4
# ### Ответ:
# * 4.1 Сколько в среднем стоят дома, у которых 2 спальни?
# Стоимость составляет 401372.681884058
# * 4.2 Какая в среднем общая площадь домов, у которых стоимость больше 600 000?
# Средняя площадь 20442.524776214832
# * 4.3 Как много домов коснулся ремонт?
# Из общего колличества домов 21613 единиц, ремонт сделан только в 914
#
# * 4.4 Насколько в среднем стоимость домов с оценкой grade домов выше 10 отличается от стоимости домов с оценкой grade меньше 4?
# Стоимость домов в с оценкой выше 10 в среднем составляет 1678635.12, а с оценкой меньше 4 = 189750.0

# %%
df[df['bedrooms'] == 2]['price'].mean()
# Out:
# 401372.681884058

# %%
df[df['price'] > 600000]['sqft_lot'].mean()
# Out:
# 20442.524776214832

# %%
df[df['grade'] > 10]['price'].mean()
# Out:
# 1678635.1175298805

# %%
df[df['grade'] < 4]['price'].mean()
# Out:
# 189750.0

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %% [markdown]
# ## Задача №5
# ### Ответ:
# * 5.1 Выберите дом клиенту  Клиент хочет дом с видом на набережную, как минимум с тремя ванными и с подвалом. Сколько вариантов есть у клиента?
# homeone
# * 5.2 Выберите дом клиенту Клиент хочет дом либо с очень красивым видом из окна, либо с видом на набережную, в очень хорошем состоянии и год постройки не меньше 1980 года. В какой ценовом диапазоне будут дома?
# hometwo
# Средняя стоимость такой квартиры будет 1233906.695
# * 5.3 Выберите дом клиенту Клиент хочет дом без подвала, с двумя этажами, стоимостью до 150000. Какая оценка по состоянию у таких домов в среднем?
# Средняя стоимость такой квартиры будет 131928.57142857142
# homethree

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
homeone = df[ (df ['bathrooms'] >= 3) & (df ['view'] > 0)]
homeone
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15     9297300055  20150124T000000   650000.0         4       3.00
# 58     7922800400  20140827T000000   951000.0         5       3.25
# 153    7855801670  20150401T000000  2250000.0         4       3.25
# 185     825059270  20141121T000000  1095000.0         5       3.00
# 216      46100204  20150221T000000  1505000.0         5       3.00
# ...           ...              ...        ...       ...        ...
# 21521  7430500110  20141209T000000  1378000.0         5       3.50
# 21540   715010530  20150113T000000  1881580.0         5       3.50
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
# 21579  7011201004  20140529T000000   645000.0         3       3.25
# 21593  8672200110  20150317T000000  1088000.0         5       3.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15            2950      5000     2.0           0     3  ...      9
# ...

# %%
hometwo = df[(df ['sqft_above'] >= 1980) & (df ['view'] > 0)]['price'].mean()
hometwo
# Out:
# 1233906.6952288218

# %%
homethree = df[(df ['sqft_basement'] == 0) & (df ['floors'] == 2)& (df ['price'] <= 150000)]['price'].mean()
homethree
# Out:
# 131928.57142857142
